# %% [markdown]
# <a href="https://colab.research.google.com/github/Chekuru-Ravi/hello-world/blob/master/1_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# basic data types - int float str bool
# pythonic data types - list tuples sets dict
# if elif else
# for while - break continue
# functions

# %% [markdown]
# # What is Pandas?

# %% [markdown]
# Pandas is one of the most important libraries of Python.
# </br>
# Pandas has data structures for data analysis. The most used of these are Series and DataFrame data structures. Series is one dimensional, that is, it consists of a column. Data frame is two-dimensional, i.e. it consists of rows and columns.

# %%
# Pandas -> Series/DataFrame

# %%
# pip install numpy

# %%
# pip install pandas

# %%
import numpy  as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
np.__version__
# Out:
# '2.0.2'

# %%
# Series : single column in an excel file!
# 1d array which can store multiple types of data!

# %%
obj = pd.Series([1,1.2,"upgrad",True])
obj
# Out:
# 0         1
# 1       1.2
# 2    upgrad
# 3      True
# dtype: object

# %%
# Tabular structure | index is automatically added | dtype!

# %%
obj[0]
# Out:
# 1

# %%
obj[1]
# Out:
# 1.2

# %%
obj2 = pd.Series([1,"John",3.5,True],
               index=["a","b","c","d"]
                )
obj2
# Out:
# a       1
# b    John
# c     3.5
# d    True
# dtype: object

# %%
# obj2["B"] # case sensitive language!

# %%
obj2['b']
# Out:
# 'John'

# %%
# list  - []
# tuple - ()
# set   - {}
# dict  - {k:v}

# %%
score={"Jane":69, "Bill":80,"Elon":85,"Tom":75,"Tim":95}
type(score)
# Out:
# dict

# %%
score.keys()
# Out:
# dict_keys(['Jane', 'Bill', 'Elon', 'Tom', 'Tim'])

# %%
score.values()
# Out:
# dict_values([69, 80, 85, 75, 95])

# %%
score
# Out:
# {'Jane': 69, 'Bill': 80, 'Elon': 85, 'Tom': 75, 'Tim': 95}

# %%
name = pd.Series(score)
print(name)
# Out:
# Jane    69
# Bill    80
# Elon    85
# Tom     75
# Tim     95
# dtype: int64

# %%
# index  -> keys of the dict
# values -> values of the dict

# %%
20 > 100
# Out:
# False

# %%
100 > 20
# Out:
# True

# %%
name
# Out:
# Jane    69
# Bill    80
# Elon    85
# Tom     75
# Tim     95
# dtype: int64

# %%
name > 80
# 1. 5 True or False
# 2. names of all people who scored more than 80
# Out:
# Jane    False
# Bill    False
# Elon     True
# Tom     False
# Tim      True
# dtype: bool

# %%
# Want all names who scored greater than 80

# %%
name[name>80]
# Out:
# Elon    85
# Tim     95
# dtype: int64
